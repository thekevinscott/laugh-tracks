# %%
# Samples for mixing noise in as data
# augmentation
files = [
    
'wFJD5znEtL0',
'a8vaVbT_lX0',
's-mlPE8pxs4',
'UkSfp3XHSko',
'i6uuzb6ASHg',
'c6PrtLXm8qY',
'eKuLq4_pNhQ',
'8GxqvnQyaxs',
'mfokPqeSNcw',
'JMNyDtib6Y4',
'U1PHpkdvNOs',
'rPu_d4SSOPk',
'qAnIOCIBFR4',
'yKTvAP06ECM',
'634TC7Feku4',
'Dph6ynRVyUc',
'NHopJHSlVo4',
'Wr2j1L9b9GU',
'iE9HMudybyc',
'gZnE8zcUUUE',
'hK0Q8b6QhDo',
'r7dWsJ-mEyI',
'0p9s7kuG0VU',
'miRY3FPCKts',
'sgVkalXmzfU',
'bIHHUEP98_c',
'f3XhcK5KiIk',
'aZFXT1aJe5U',
'Ys_EItzrOq8',
    '5Pf19jV1NYw',
    'Xu9y80I8ALo',
    'jGjL1bkgXkQ',
    'DuzTpO1_Vcg',
    'eIZcAH5Rhe4',
    'EfxQAIUehAE',
    'e6Y2uQn_wvc',
    '5YFU4ZK1zIU',
    'AvL7YgTY1KY',
    'BovyveAztv0',
    'SKTkKA1vSu4',
    '-dMGM1JdSQs',
    'CsqXftqOfx4',
    'g-nE-zrIhKc',
    'o_LpaA9AUbY',
    'ce8u2OFrrXM',
    'YjBO1bONqgc',
    'wAEvT29AOOU',
    'wspnO_wg0S8',
]

ids = ','.join(files)

# !python3 download_from_youtube.py --target noise_samples --ids $ids
# Out:
# target noise_samples/wFJD5znEtL0
# target noise_samples/a8vaVbT_lX0
# target noise_samples/s-mlPE8pxs4
# target noise_samples/UkSfp3XHSko
# target noise_samples/i6uuzb6ASHg
# target noise_samples/c6PrtLXm8qY
# target noise_samples/eKuLq4_pNhQ
# target noise_samples/8GxqvnQyaxs
# target noise_samples/mfokPqeSNcw
# target noise_samples/JMNyDtib6Y4
# target noise_samples/U1PHpkdvNOs
# target noise_samples/rPu_d4SSOPk
# target noise_samples/qAnIOCIBFR4
# target noise_samples/yKTvAP06ECM
# target noise_samples/634TC7Feku4
# target noise_samples/Dph6ynRVyUc
# target noise_samples/NHopJHSlVo4
# target noise_samples/Wr2j1L9b9GU
# target noise_samples/iE9HMudybyc
# target noise_samples/gZnE8zcUUUE
# target noise_samples/hK0Q8b6QhDo
# target noise_samples/r7dWsJ-mEyI
# target noise_samples/0p9s7kuG0VU
# target noise_samples/miRY3FPCKts
# target noise_samples/sgVkalXmzfU
# target noise_samples/bIHHUEP98_c
# target noise_samples/f3XhcK5KiIk
# target noise_samples/aZFXT1aJe5U
# ...

# %%
#samples = getLaughTracks(None, False, False)
#print(np.array(samples[0]).shape)
# Out:
# getting data for ['samples/laughter/16-lfVsYaxc.wav', 'samples/laughter/3IC76o_lhFw.wav', 'samples/laughter/3LG9A7fUrPs.wav', 'samples/laughter/4B06Bh3i8Ms.wav', 'samples/laughter/4z12ijqiFrY.wav', 'samples/laughter/At6oITvbENo.wav', 'samples/laughter/C80iIItZHFM.wav', 'samples/laughter/DZZORgAVFJw.wav', 'samples/laughter/EzS7y_3GhKA.wav', 'samples/laughter/IlMPU4AVU20.wav', 'samples/laughter/Pz_DMUe4tXc.wav', 'samples/laughter/R1hbmMfoT9c.wav', 'samples/laughter/T_wNZhcw9x8.wav', 'samples/laughter/augmented/16-lfVsYaxc_0_changeGain.wav', 'samples/laughter/augmented/16-lfVsYaxc_1_addCompression.wav', 'samples/laughter/augmented/16-lfVsYaxc_2_mixWith.wav', 'samples/laughter/augmented/16-lfVsYaxc_3_mixWith.wav', 'samples/laughter/augmented/16-lfVsYaxc_4_mixWith.wav', 'samples/laughter/augmented/3IC76o_lhFw_0_changeGain.wav', 'samples/laughter/augmented/3IC76o_lhFw_1_addCompression.wav', 'samples/laughter/augmented/3IC76o_lhFw_2_mixWith.wav', 'samples/laughter/augmented/3IC76o_lhFw_3_mi
# ...

# %%
# files for notlaughter-test
ids = ','.join([
    'ddVE1mN5_lU',
    'jFS9rRTXue8',
])
# !python3 download_from_youtube.py --target samples/notlaughter-test --ids $ids
# Out:
# ids ['ddVE1mN5_lU', 'jFS9rRTXue8']
# target samples/notlaughter-test/ddVE1mN5_lU
# id ddVE1mN5_lU
# samples/notlaughter-test/ddVE1mN5_lU.wav
# WARNING: Assuming --restrict-filenames since file system encoding cannot encode all characters. Set the LC_ALL environment variable to fix this.
# [youtube] ddVE1mN5_lU: Downloading webpage
# [youtube] ddVE1mN5_lU: Downloading video info webpage
# [youtube] ddVE1mN5_lU: Downloading MPD manifest
# [youtube] ddVE1mN5_lU: Downloading MPD manifest
# [dashsegments] Total fragments: 5
# [download] Destination: samples/notlaughter-test/ddVE1mN5_lU.wav
# [download] 100% of 448.61KiB in 00:01.55MiB/s ETA 00:00:23
# [ffmpeg] Correcting container in "samples/notlaughter-test/ddVE1mN5_lU.wav"
# [ffmpeg] Post-process file samples/notlaughter-test/ddVE1mN5_lU.wav exists, skipping
# target samples/notlaughter-test/jFS9rRTXue8
# id jFS9rRTXue8
# samples/notlaughter-test/jFS9rRTXue8.wav
# ...

# %%
# !python3 download_from_youtube.py --target data --ids 0Vo56kV_IXA
# Out:
# target data/0Vo56kV_IXA
# id 0Vo56kV_IXA
# data/0Vo56kV_IXA.wav
# WARNING: Assuming --restrict-filenames since file system encoding cannot encode all characters. Set the LC_ALL environment variable to fix this.
# [youtube] 0Vo56kV_IXA: Downloading webpage
# [youtube] 0Vo56kV_IXA: Downloading video info webpage
# [download] Destination: data/0Vo56kV_IXA.wav
# [download] 100% of 3.46MiB in 00:0081MiB/s ETA 00:00known ETA
# [ffmpeg] Post-process file data/0Vo56kV_IXA.wav exists, skipping
