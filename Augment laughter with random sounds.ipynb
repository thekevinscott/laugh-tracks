# %%
# !rm -rf samples/laughter/augmented
# !python3 augment_audio_data.py --input 'samples/laughter' --output 'samples/laughter/augmented' --number_of_transforms 4 --mix_dir noise_samples
# Out:
# 16-lfVsYaxc.wav 0 changeGain
# 16-lfVsYaxc.wav 1 mixWith
# 16-lfVsYaxc.wav 2 mixWith
# 16-lfVsYaxc.wav 3 mixWith
# 3IC76o_lhFw.wav 0 mixWith
# 3IC76o_lhFw.wav 1 mixWith
# 3IC76o_lhFw.wav 2 addCompression
# 3IC76o_lhFw.wav 3 changeGain
# 3LG9A7fUrPs.wav 0 addCompression
# 3LG9A7fUrPs.wav 1 mixWith
# 3LG9A7fUrPs.wav 2 mixWith
# 3LG9A7fUrPs.wav 3 mixWith
# 4B06Bh3i8Ms.wav 0 mixWith
# 4B06Bh3i8Ms.wav 1 addCompression
# 4B06Bh3i8Ms.wav 2 mixWith
# 4B06Bh3i8Ms.wav 3 mixWith
# 4z12ijqiFrY.wav 0 mixWith
# 4z12ijqiFrY.wav 1 changeGain
# 4z12ijqiFrY.wav 2 mixWith
# 4z12ijqiFrY.wav 3 addCompression
# At6oITvbENo.wav 0 mixWith
# At6oITvbENo.wav 1 mixWith
# At6oITvbENo.wav 2 changeGain
# At6oITvbENo.wav 3 mixWith
# C80iIItZHFM.wav 0 addCompression
# C80iIItZHFM.wav 1 changeGain
# C80iIItZHFM.wav 2 mixWith
# C80iIItZHFM.wav 3 mixWith
# DZZORgAVFJw.wav 0 mixWith
# DZZORgAVFJw.wav 1 mixWith
# DZZORgAVFJw.wav 2 mixWith
# DZZORgAVFJw.wav 3 mixWith
# EzS7y_3GhKA.wav 0 mixWith
# ...
