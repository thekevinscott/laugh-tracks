# %%
from audioUtils import readFolder
from random import shuffle
import IPython.display as ipd

folder = 'samples/laughter/augmented'
files = readFolder(folder)
shuffle(files)

for i in range(0, 5):
    file = files[i]
    print(file)
    display(ipd.Audio('%s/%s' % (folder, file)))
# Out:
# 3LG9A7fUrPs_0_changeGain.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 16-lfVsYaxc_2_mixWith.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 16-lfVsYaxc_4_mixWith.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 3LG9A7fUrPs_1_addCompression.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
# ...
